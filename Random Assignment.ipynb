# %%
import numpy as np
import random
from collections import deque
import matplotlib.pyplot as plt
import time

random.seed(17)
# Parameters
num_stations = 10  # Number of charging stations
station_capacity = 500  # Max capacity in KWh for each charging station
simulation_time = 1440 #Total simulation time steps
arrival_rate = 0.4 # Probability of EV arrival at each time step
charging_time_mean = 20 # Mean charging duration (time steps)
#charging_time_std = 10   # Std dev of charging duration


# Initialize charging stations
class ChargingStation:
    def __init__(self, station_id, capacity):
        self.station_id = station_id
        self.capacity = capacity
        self.current_load = 0
        self.ev_count = 0
        self.queue = deque()  # Queue to hold EVs being charged

    def add_ev(self, ev):
        self.queue.append(ev)
        self.current_load += ev.energy
        self.ev_count += 1

    def remove_ev(self):
        if self.queue:
            ev = self.queue.popleft()
            self.current_load -= ev.energy
            self.ev_count -= 1
            return ev
        return None

    def average_remaining_time(self):
        if self.ev_count == 0:
            return float(0)  # No EVs, so return a zero - No remaining time
        total_remaining_time = sum([ev.remaining_time for ev in self.queue])
        return total_remaining_time / self.ev_count

# EV class
class EV:
    def __init__(self, ev_id, energy, charging_duration, arrival_time):
        self.ev_id = ev_id
        self.energy = energy
        self.charging_duration = charging_duration
        self.remaining_time = charging_duration
        self.waiting_time = 1000
        self.arrival_time = arrival_time
        self.departure_time = None
        self.assigned_station = -1

    def charge_one_step(self):
        if self.remaining_time > 0:
            self.remaining_time -= 1
            if self.remaining_time == 0:
                self.departure_time = None  # To be set when removed from station

# Initialize stations
stations = [ChargingStation(i, station_capacity) for i in range(num_stations)]

# Simulation state
current_time = 0
ev_id_counter = 0
active_evs = []  # List to hold currently charging EVs
departed_evs = []  # List to hold departed EVs
par_list = []  # List to store peak-to-average ratio for each time step
par_time_list = [] # List to store peak-to-average waiting time ratio for each time step
served_evs_per_step = np.zeros(simulation_time)  # List to track the number of served EVs per time step
unassigned_evs_per_step = np.zeros(simulation_time)  # List to track the number of unassigned EVs per time step
arriving_evs_per_step = np.zeros(simulation_time)  # List to track the number of arriving EVs per time step
departing_evs_per_step = np.zeros(simulation_time)  # List to track the number of departing EVs per time step
waitingtimeseries = np.zeros(simulation_time)

# Function to calculate the peak-to-average ratio
def calculate_par(stations):
    loads = [station.current_load for station in stations]
    peak_load = max(loads)
    average_load = sum(loads) / len(stations)
    if average_load > 0:  # Avoid division by zero
        par = peak_load / average_load
    else:
        par = 0  # If average load is zero, PAR is not meaningful
    return par

# Function to calculate the peak-to-average ratio
def calculate_avgwaiting_time(evs):
    meantime = [np.mean(ev.waiting_time) for ev in evs]
    return meantime

def calculate_par_time(evs):
    loads = [np.mean(ev.waiting_time) for ev in evs]
    peak_load = max(loads)
    average_load = sum(loads) / len(evs)
    if average_load > 0:  # Avoid division by zero
        par = peak_load / average_load
        #par = loads
    else:
        par = 0  # If average load is zero, PAR is not meaningful
    return par

# Function to calculate the composite score for station selection
def calculate_station_score(station, ev_energy):
    current_load = station.current_load
    proximity_to_capacity = (current_load + ev_energy) / station.capacity  # How close to capacity
    avg_remaining_time = station.average_remaining_time()  # Avg time for current EVs to finish charging

    # Composite score: current load + penalty for proximity to capacity + benefit for short remaining times
    #score = current_load + proximity_to_capacity * 10 + avg_remaining_time * 10
    score = avg_remaining_time #Use the average waiting time only as my decision making criteria
    
    return score

def assign_ev_to_station(ev, stations):
    best_station = None
    best_score = float('inf')
    
    for station in stations:
        # Calculate the score for this station
        score = calculate_station_score(station, ev.energy)
        if random.uniform(0,1)>0.5:  # Ensure capacity limit
            best_score = score
            best_station = station
    
    # Assign to the best station
    if best_station is not None:
        best_station.add_ev(ev)
        ev.assigned_station = best_station.station_id
        ev.waiting_time = best_score
        return True  # EV was assigned successfully
    else:
        return False  # EV could not be assigned

timelist = []
stlist = []
loadlist = []
evlist = []

start_time = time.time()
# Simulation loop
for current_time in range(simulation_time):
    print(f"\n--- Time Step {current_time} ---")

    # 1. Handle EV departures
    departing_evs = 0
    for station in stations:
        if station.queue and station.queue[0].remaining_time <= 0:
            ev = station.remove_ev()
            ev.departure_time = current_time
            departed_evs.append(ev)
            active_evs.remove(ev)
            departing_evs += 1  # Track departing EVs
            print(f"EV {ev.ev_id} has departed from Station {station.station_id + 1}.")
            departing_evs_per_step[current_time] += 1

    #departing_evs_per_step.append(departing_evs)
    #departing_evs_per_step[current_time] += departing_evs

    # 2. Update remaining charging time for active EVs
    for ev in active_evs:
        ev.charge_one_step()

    # 3. Handle EV arrivals
    served_evs = 0
    unassigned_evs = 0
    arriving_evs = 0
    if np.random.poisson(arrival_rate) < arrival_rate: # Change this to a poisson RV
        energy = np.random.randint(10, 50)
        charging_duration = max(1, int(np.random.exponential(charging_time_mean))) # Change this to a Poisson service time too
        
        #charging_duration = max(1, int(10*energy/22)) # Deterministic service time depending on the charging rate (22 kW) and requested energy.
        
        # Start working on discrete event simulators (SimEvent) on MATLAB to trigger the arrival of EVs as events.
        # Synchronization is important between the arrivals clock and the services clock
        # If all the stations are not connected to the same feeder, then the idea of load balancing does not really apply.
        # (Add this as an assumption to my conference paper: Assume that all the stations are connected to the same power feeder to achieve the desired grid-related objective.)
        # Then I can plot peak-to-average ratio of the waiting time to assess the system rather than the peak-to-average energy ratio.
        # Should we consider batch queuing process or not?
        
        ev = EV(ev_id_counter, energy, charging_duration, current_time)
        ev_id_counter += 1
        active_evs.append(ev)
        arriving_evs += 1
        print(f"EV {ev.ev_id} has arrived with {ev.energy} KWh and needs {ev.charging_duration} time steps.")
        
        # Attempt to assign the EV to a station
        if assign_ev_to_station(ev, stations):
            served_evs += 1  # Successfully assigned
        else:
            unassigned_evs += 1  # Could not be assigned

    arriving_evs_per_step[current_time] += arriving_evs
    #served_evs_per_step[current_time] += served_evs
    unassigned_evs_per_step[current_time] += unassigned_evs

    # 4. Calculate peak-to-average ratio for this time step
    par = calculate_par(stations)
    par_list.append(par)  # Store PAR value for this time step
    par_time = calculate_par_time(active_evs) 
    par_time_list.append(par_time)
    waitingtimeseries[current_time] = np.mean(calculate_avgwaiting_time(active_evs))

    # 5. Display current state (optional)
    for station in stations:
        print(f"Station {station.station_id + 1}: Load={station.current_load} KWh, EVs={station.ev_count}")
        timelist.append(current_time)
        stlist.append(station.station_id + 1)
        loadlist.append(station.current_load)
        evlist.append(station.ev_count)
        current_loads = [station.current_load for station in stations]
        served_evs_per_step[current_time] += station.ev_count
    print(f"Number of EVs currently served is {served_evs_per_step[current_time]}")
    
end_time = time.time()

# Final Results
print("\n--- Simulation Completed ---\n")
for i, station in enumerate(stations):
    print(f"Station {i + 1} final load: {station.current_load} KWh, serving {station.ev_count} EVs.")
print(f"Total EVs Departed: {len(departed_evs)}")
print(f"Total EVs Active: {len(active_evs)}")
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
print(f"Average PAR for Station Energy across {simulation_time} steps is {np.mean(par_list)}.")
print(f"Average PAR Waiting Time across {simulation_time} steps is {np.mean(par_time_list)}.")
print(f"Average Waiting Time across {simulation_time} steps is {np.mean(waitingtimeseries)}.")

data = {'Time':range(simulation_time), 'PAR_Energy': par_list, 'PAR_Time': par_time_list, 'ArrivingEVs':arriving_evs_per_step, "DepartingEVs":departing_evs_per_step, "ServedEVs": served_evs_per_step, "UnassignedEVs":unassigned_evs_per_step}
import pandas as pd
DF = pd.DataFrame(data)
DF.to_csv('RandomAssignmentResults.csv', index=False)

# Plot Peak-to-Average Ratio over Time
plt.figure(figsize=(10, 6))
plt.plot(range(simulation_time), par_list, label='Peak-to-Average Ratio')
plt.xlabel('Time Step')
plt.ylabel('Peak-to-Average Energy Ratio')
plt.title('Peak-to-Average Ratio of Load Across Charging Ports at Each Time Step')
plt.legend()
plt.grid(True)
plt.savefig("PAER_Random.jpg")
plt.show()
# Out:
# --- Time Step 0 ---
# EV 0 has arrived with 41 KWh and needs 2 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=41 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=0 KWh, EVs=0
# Station 10: Load=0 KWh, EVs=0
# Number of EVs currently served is 1.0
#
# --- Time Step 1 ---
# EV 1 has arrived with 24 KWh and needs 2 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=41 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=0 KWh, EVs=0
# Station 10: Load=24 KWh, EVs=1
# Number of EVs currently served is 2.0
#
# --- Time Step 2 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=41 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=0 KWh, EVs=0
# Station 10: Load=24 KWh, EVs=1
# Number of EVs currently served is 2.0
#
# --- Time Step 3 ---
# EV 0 has departed from Station 7.
# EV 2 has arrived with 22 KWh and needs 31 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=24 KWh, EVs=1
# Number of EVs currently served is 2.0
#
# --- Time Step 4 ---
# EV 1 has departed from Station 10.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=0 KWh, EVs=0
# Number of EVs currently served is 1.0
#
# --- Time Step 5 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=0 KWh, EVs=0
# Number of EVs currently served is 1.0
#
# --- Time Step 6 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=0 KWh, EVs=0
# Number of EVs currently served is 1.0
#
# --- Time Step 7 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=0 KWh, EVs=0
# Number of EVs currently served is 1.0
#
# --- Time Step 8 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=0 KWh, EVs=0
# Number of EVs currently served is 1.0
#
# --- Time Step 9 ---
# EV 3 has arrived with 26 KWh and needs 1 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=26 KWh, EVs=1
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=0 KWh, EVs=0
# Number of EVs currently served is 2.0
#
# --- Time Step 10 ---
# EV 4 has arrived with 23 KWh and needs 30 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=26 KWh, EVs=1
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=23 KWh, EVs=1
# Number of EVs currently served is 3.0
#
# --- Time Step 11 ---
# EV 3 has departed from Station 8.
# EV 5 has arrived with 46 KWh and needs 2 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=69 KWh, EVs=2
# Number of EVs currently served is 3.0
#
# --- Time Step 12 ---
# EV 6 has arrived with 15 KWh and needs 8 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=15 KWh, EVs=1
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=69 KWh, EVs=2
# Number of EVs currently served is 4.0
#
# --- Time Step 13 ---
# EV 7 has arrived with 46 KWh and needs 12 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=15 KWh, EVs=1
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=115 KWh, EVs=3
# Number of EVs currently served is 5.0
#
# --- Time Step 14 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=15 KWh, EVs=1
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=115 KWh, EVs=3
# Number of EVs currently served is 5.0
#
# --- Time Step 15 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=15 KWh, EVs=1
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=115 KWh, EVs=3
# Number of EVs currently served is 5.0
#
# --- Time Step 16 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=15 KWh, EVs=1
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=115 KWh, EVs=3
# Number of EVs currently served is 5.0
#
# --- Time Step 17 ---
# EV 8 has arrived with 37 KWh and needs 3 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=37 KWh, EVs=1
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=15 KWh, EVs=1
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=115 KWh, EVs=3
# Number of EVs currently served is 6.0
#
# --- Time Step 18 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=37 KWh, EVs=1
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=15 KWh, EVs=1
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=115 KWh, EVs=3
# Number of EVs currently served is 6.0
#
# --- Time Step 19 ---
# EV 9 has arrived with 35 KWh and needs 18 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=37 KWh, EVs=1
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=15 KWh, EVs=1
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=150 KWh, EVs=4
# Number of EVs currently served is 7.0
#
# --- Time Step 20 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=37 KWh, EVs=1
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=15 KWh, EVs=1
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=150 KWh, EVs=4
# Number of EVs currently served is 7.0
#
# --- Time Step 21 ---
# EV 8 has departed from Station 4.
# EV 6 has departed from Station 8.
# EV 10 has arrived with 26 KWh and needs 18 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=26 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=150 KWh, EVs=4
# Number of EVs currently served is 6.0
#
# --- Time Step 22 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=26 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=150 KWh, EVs=4
# Number of EVs currently served is 6.0
#
# --- Time Step 23 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=26 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=22 KWh, EVs=1
# Station 10: Load=150 KWh, EVs=4
# Number of EVs currently served is 6.0
#
# --- Time Step 24 ---
# EV 11 has arrived with 32 KWh and needs 34 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=26 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=54 KWh, EVs=2
# Station 10: Load=150 KWh, EVs=4
# Number of EVs currently served is 7.0
#
# --- Time Step 25 ---
# EV 12 has arrived with 26 KWh and needs 1 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=26 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=54 KWh, EVs=2
# Station 10: Load=176 KWh, EVs=5
# Number of EVs currently served is 8.0
#
# --- Time Step 26 ---
# EV 13 has arrived with 22 KWh and needs 5 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=26 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=54 KWh, EVs=2
# Station 10: Load=198 KWh, EVs=6
# Number of EVs currently served is 9.0
#
# --- Time Step 27 ---
# EV 14 has arrived with 42 KWh and needs 16 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=26 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=96 KWh, EVs=3
# Station 10: Load=198 KWh, EVs=6
# Number of EVs currently served is 10.0
#
# --- Time Step 28 ---
# EV 15 has arrived with 13 KWh and needs 6 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=26 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=96 KWh, EVs=3
# Station 10: Load=211 KWh, EVs=7
# Number of EVs currently served is 11.0
#
# --- Time Step 29 ---
# EV 16 has arrived with 40 KWh and needs 5 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=26 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=96 KWh, EVs=3
# Station 10: Load=251 KWh, EVs=8
# Number of EVs currently served is 12.0
#
# --- Time Step 30 ---
# EV 17 has arrived with 12 KWh and needs 10 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=26 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=96 KWh, EVs=3
# Station 10: Load=263 KWh, EVs=9
# Number of EVs currently served is 13.0
#
# --- Time Step 31 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=26 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=96 KWh, EVs=3
# Station 10: Load=263 KWh, EVs=9
# Number of EVs currently served is 13.0
#
# --- Time Step 32 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=26 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=96 KWh, EVs=3
# Station 10: Load=263 KWh, EVs=9
# Number of EVs currently served is 13.0
#
# --- Time Step 33 ---
# EV 18 has arrived with 10 KWh and needs 13 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=26 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=96 KWh, EVs=3
# Station 10: Load=273 KWh, EVs=10
# Number of EVs currently served is 14.0
#
# --- Time Step 34 ---
# EV 19 has arrived with 14 KWh and needs 35 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=40 KWh, EVs=2
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=96 KWh, EVs=3
# Station 10: Load=273 KWh, EVs=10
# Number of EVs currently served is 15.0
#
# --- Time Step 35 ---
# EV 2 has departed from Station 9.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=40 KWh, EVs=2
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=74 KWh, EVs=2
# Station 10: Load=273 KWh, EVs=10
# Number of EVs currently served is 14.0
#
# --- Time Step 36 ---
# EV 20 has arrived with 43 KWh and needs 113 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=40 KWh, EVs=2
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=117 KWh, EVs=3
# Station 10: Load=273 KWh, EVs=10
# Number of EVs currently served is 15.0
#
# --- Time Step 37 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=40 KWh, EVs=2
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=117 KWh, EVs=3
# Station 10: Load=273 KWh, EVs=10
# Number of EVs currently served is 15.0
#
# --- Time Step 38 ---
# EV 21 has arrived with 40 KWh and needs 24 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=40 KWh, EVs=2
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=117 KWh, EVs=3
# Station 10: Load=313 KWh, EVs=11
# Number of EVs currently served is 16.0
#
# --- Time Step 39 ---
# EV 22 has arrived with 30 KWh and needs 3 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=40 KWh, EVs=2
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=147 KWh, EVs=4
# Station 10: Load=313 KWh, EVs=11
# Number of EVs currently served is 17.0
#
# --- Time Step 40 ---
# EV 10 has departed from Station 7.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=14 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=147 KWh, EVs=4
# Station 10: Load=313 KWh, EVs=11
# Number of EVs currently served is 16.0
#
# --- Time Step 41 ---
# EV 4 has departed from Station 10.
# EV 23 has arrived with 10 KWh and needs 9 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=10 KWh, EVs=1
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=14 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=147 KWh, EVs=4
# Station 10: Load=290 KWh, EVs=10
# Number of EVs currently served is 16.0
#
# --- Time Step 42 ---
# EV 5 has departed from Station 10.
# EV 24 has arrived with 45 KWh and needs 5 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=10 KWh, EVs=1
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=14 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=192 KWh, EVs=5
# Station 10: Load=244 KWh, EVs=9
# Number of EVs currently served is 16.0
#
# --- Time Step 43 ---
# EV 7 has departed from Station 10.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=10 KWh, EVs=1
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=14 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=192 KWh, EVs=5
# Station 10: Load=198 KWh, EVs=8
# Number of EVs currently served is 15.0
#
# --- Time Step 44 ---
# EV 9 has departed from Station 10.
# EV 25 has arrived with 10 KWh and needs 2 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=10 KWh, EVs=1
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=14 KWh, EVs=1
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=192 KWh, EVs=5
# Station 10: Load=173 KWh, EVs=8
# Number of EVs currently served is 15.0
#
# --- Time Step 45 ---
# EV 12 has departed from Station 10.
# EV 26 has arrived with 18 KWh and needs 21 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=10 KWh, EVs=1
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=32 KWh, EVs=2
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=192 KWh, EVs=5
# Station 10: Load=147 KWh, EVs=7
# Number of EVs currently served is 15.0
#
# --- Time Step 46 ---
# EV 13 has departed from Station 10.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=10 KWh, EVs=1
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=32 KWh, EVs=2
# Station 8: Load=0 KWh, EVs=0
# Station 9: Load=192 KWh, EVs=5
# Station 10: Load=125 KWh, EVs=6
# Number of EVs currently served is 14.0
#
# --- Time Step 47 ---
# EV 15 has departed from Station 10.
# EV 27 has arrived with 11 KWh and needs 41 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=10 KWh, EVs=1
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=32 KWh, EVs=2
# Station 8: Load=11 KWh, EVs=1
# Station 9: Load=192 KWh, EVs=5
# Station 10: Load=112 KWh, EVs=5
# Number of EVs currently served is 14.0
#
# --- Time Step 48 ---
# EV 16 has departed from Station 10.
# EV 28 has arrived with 46 KWh and needs 9 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=10 KWh, EVs=1
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=32 KWh, EVs=2
# Station 8: Load=11 KWh, EVs=1
# Station 9: Load=192 KWh, EVs=5
# Station 10: Load=118 KWh, EVs=5
# Number of EVs currently served is 14.0
#
# --- Time Step 49 ---
# EV 17 has departed from Station 10.
# EV 29 has arrived with 39 KWh and needs 2 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=10 KWh, EVs=1
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=32 KWh, EVs=2
# Station 8: Load=50 KWh, EVs=2
# Station 9: Load=192 KWh, EVs=5
# Station 10: Load=106 KWh, EVs=4
# Number of EVs currently served is 14.0
#
# --- Time Step 50 ---
# EV 18 has departed from Station 10.
# EV 30 has arrived with 11 KWh and needs 27 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=10 KWh, EVs=1
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=32 KWh, EVs=2
# Station 8: Load=50 KWh, EVs=2
# Station 9: Load=203 KWh, EVs=6
# Station 10: Load=96 KWh, EVs=3
# Number of EVs currently served is 14.0
#
# --- Time Step 51 ---
# EV 23 has departed from Station 4.
# EV 31 has arrived with 32 KWh and needs 16 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=32 KWh, EVs=2
# Station 8: Load=50 KWh, EVs=2
# Station 9: Load=235 KWh, EVs=7
# Station 10: Load=96 KWh, EVs=3
# Number of EVs currently served is 14.0
#
# --- Time Step 52 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=32 KWh, EVs=2
# Station 8: Load=50 KWh, EVs=2
# Station 9: Load=235 KWh, EVs=7
# Station 10: Load=96 KWh, EVs=3
# Number of EVs currently served is 14.0
#
# --- Time Step 53 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=32 KWh, EVs=2
# Station 8: Load=50 KWh, EVs=2
# Station 9: Load=235 KWh, EVs=7
# Station 10: Load=96 KWh, EVs=3
# Number of EVs currently served is 14.0
#
# --- Time Step 54 ---
# EV 32 has arrived with 47 KWh and needs 34 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=32 KWh, EVs=2
# Station 8: Load=50 KWh, EVs=2
# Station 9: Load=235 KWh, EVs=7
# Station 10: Load=143 KWh, EVs=4
# Number of EVs currently served is 15.0
#
# --- Time Step 55 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=32 KWh, EVs=2
# Station 8: Load=50 KWh, EVs=2
# Station 9: Load=235 KWh, EVs=7
# Station 10: Load=143 KWh, EVs=4
# Number of EVs currently served is 15.0
#
# --- Time Step 56 ---
# EV 33 has arrived with 44 KWh and needs 2 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=32 KWh, EVs=2
# Station 8: Load=50 KWh, EVs=2
# Station 9: Load=235 KWh, EVs=7
# Station 10: Load=187 KWh, EVs=5
# Number of EVs currently served is 16.0
#
# --- Time Step 57 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=32 KWh, EVs=2
# Station 8: Load=50 KWh, EVs=2
# Station 9: Load=235 KWh, EVs=7
# Station 10: Load=187 KWh, EVs=5
# Number of EVs currently served is 16.0
#
# --- Time Step 58 ---
# EV 34 has arrived with 49 KWh and needs 8 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=49 KWh, EVs=1
# Station 7: Load=32 KWh, EVs=2
# Station 8: Load=50 KWh, EVs=2
# Station 9: Load=235 KWh, EVs=7
# Station 10: Load=187 KWh, EVs=5
# Number of EVs currently served is 17.0
#
# --- Time Step 59 ---
# EV 11 has departed from Station 9.
# EV 35 has arrived with 45 KWh and needs 6 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=49 KWh, EVs=1
# Station 7: Load=32 KWh, EVs=2
# Station 8: Load=50 KWh, EVs=2
# Station 9: Load=203 KWh, EVs=6
# Station 10: Load=232 KWh, EVs=6
# Number of EVs currently served is 17.0
#
# --- Time Step 60 ---
# EV 14 has departed from Station 9.
# EV 36 has arrived with 42 KWh and needs 21 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=49 KWh, EVs=1
# Station 7: Load=32 KWh, EVs=2
# Station 8: Load=50 KWh, EVs=2
# Station 9: Load=161 KWh, EVs=5
# Station 10: Load=274 KWh, EVs=7
# Number of EVs currently served is 17.0
#
# --- Time Step 61 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=49 KWh, EVs=1
# Station 7: Load=32 KWh, EVs=2
# Station 8: Load=50 KWh, EVs=2
# Station 9: Load=161 KWh, EVs=5
# Station 10: Load=274 KWh, EVs=7
# Number of EVs currently served is 17.0
#
# --- Time Step 62 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=49 KWh, EVs=1
# Station 7: Load=32 KWh, EVs=2
# Station 8: Load=50 KWh, EVs=2
# Station 9: Load=161 KWh, EVs=5
# Station 10: Load=274 KWh, EVs=7
# Number of EVs currently served is 17.0
#
# --- Time Step 63 ---
# EV 21 has departed from Station 10.
# EV 37 has arrived with 48 KWh and needs 30 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=49 KWh, EVs=1
# Station 7: Load=80 KWh, EVs=3
# Station 8: Load=50 KWh, EVs=2
# Station 9: Load=161 KWh, EVs=5
# Station 10: Load=234 KWh, EVs=6
# Number of EVs currently served is 17.0
#
# --- Time Step 64 ---
# EV 25 has departed from Station 10.
# EV 38 has arrived with 43 KWh and needs 45 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=49 KWh, EVs=1
# Station 7: Load=80 KWh, EVs=3
# Station 8: Load=50 KWh, EVs=2
# Station 9: Load=204 KWh, EVs=6
# Station 10: Load=224 KWh, EVs=5
# Number of EVs currently served is 17.0
#
# --- Time Step 65 ---
# EV 28 has departed from Station 10.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=49 KWh, EVs=1
# Station 7: Load=80 KWh, EVs=3
# Station 8: Load=50 KWh, EVs=2
# Station 9: Load=204 KWh, EVs=6
# Station 10: Load=178 KWh, EVs=4
# Number of EVs currently served is 16.0
#
# --- Time Step 66 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=49 KWh, EVs=1
# Station 7: Load=80 KWh, EVs=3
# Station 8: Load=50 KWh, EVs=2
# Station 9: Load=204 KWh, EVs=6
# Station 10: Load=178 KWh, EVs=4
# Number of EVs currently served is 16.0
#
# --- Time Step 67 ---
# EV 34 has departed from Station 6.
# EV 39 has arrived with 12 KWh and needs 9 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=92 KWh, EVs=4
# Station 8: Load=50 KWh, EVs=2
# Station 9: Load=204 KWh, EVs=6
# Station 10: Load=178 KWh, EVs=4
# Number of EVs currently served is 16.0
#
# --- Time Step 68 ---
# EV 40 has arrived with 26 KWh and needs 89 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=92 KWh, EVs=4
# Station 8: Load=76 KWh, EVs=3
# Station 9: Load=204 KWh, EVs=6
# Station 10: Load=178 KWh, EVs=4
# Number of EVs currently served is 17.0
#
# --- Time Step 69 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=92 KWh, EVs=4
# Station 8: Load=76 KWh, EVs=3
# Station 9: Load=204 KWh, EVs=6
# Station 10: Load=178 KWh, EVs=4
# Number of EVs currently served is 17.0
#
# --- Time Step 70 ---
# EV 19 has departed from Station 7.
# EV 41 has arrived with 21 KWh and needs 34 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=78 KWh, EVs=3
# Station 8: Load=76 KWh, EVs=3
# Station 9: Load=204 KWh, EVs=6
# Station 10: Load=199 KWh, EVs=5
# Number of EVs currently served is 17.0
#
# --- Time Step 71 ---
# EV 26 has departed from Station 7.
# EV 42 has arrived with 29 KWh and needs 55 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=105 KWh, EVs=4
# Station 9: Load=204 KWh, EVs=6
# Station 10: Load=199 KWh, EVs=5
# Number of EVs currently served is 17.0
#
# --- Time Step 72 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=105 KWh, EVs=4
# Station 9: Load=204 KWh, EVs=6
# Station 10: Load=199 KWh, EVs=5
# Number of EVs currently served is 17.0
#
# --- Time Step 73 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=105 KWh, EVs=4
# Station 9: Load=204 KWh, EVs=6
# Station 10: Load=199 KWh, EVs=5
# Number of EVs currently served is 17.0
#
# --- Time Step 74 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=105 KWh, EVs=4
# Station 9: Load=204 KWh, EVs=6
# Station 10: Load=199 KWh, EVs=5
# Number of EVs currently served is 17.0
#
# --- Time Step 75 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=105 KWh, EVs=4
# Station 9: Load=204 KWh, EVs=6
# Station 10: Load=199 KWh, EVs=5
# Number of EVs currently served is 17.0
#
# --- Time Step 76 ---
# EV 43 has arrived with 32 KWh and needs 22 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=105 KWh, EVs=4
# Station 9: Load=236 KWh, EVs=7
# Station 10: Load=199 KWh, EVs=5
# Number of EVs currently served is 18.0
#
# --- Time Step 77 ---
# EV 44 has arrived with 39 KWh and needs 4 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=105 KWh, EVs=4
# Station 9: Load=236 KWh, EVs=7
# Station 10: Load=238 KWh, EVs=6
# Number of EVs currently served is 19.0
#
# --- Time Step 78 ---
# EV 45 has arrived with 36 KWh and needs 6 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=141 KWh, EVs=5
# Station 9: Load=236 KWh, EVs=7
# Station 10: Load=238 KWh, EVs=6
# Number of EVs currently served is 20.0
#
# --- Time Step 79 ---
# EV 46 has arrived with 46 KWh and needs 1 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=187 KWh, EVs=6
# Station 9: Load=236 KWh, EVs=7
# Station 10: Load=238 KWh, EVs=6
# Number of EVs currently served is 21.0
#
# --- Time Step 80 ---
# EV 47 has arrived with 46 KWh and needs 4 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=187 KWh, EVs=6
# Station 9: Load=236 KWh, EVs=7
# Station 10: Load=284 KWh, EVs=7
# Number of EVs currently served is 22.0
#
# --- Time Step 81 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=187 KWh, EVs=6
# Station 9: Load=236 KWh, EVs=7
# Station 10: Load=284 KWh, EVs=7
# Number of EVs currently served is 22.0
#
# --- Time Step 82 ---
# EV 48 has arrived with 37 KWh and needs 33 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=187 KWh, EVs=6
# Station 9: Load=236 KWh, EVs=7
# Station 10: Load=321 KWh, EVs=8
# Number of EVs currently served is 23.0
#
# --- Time Step 83 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=187 KWh, EVs=6
# Station 9: Load=236 KWh, EVs=7
# Station 10: Load=321 KWh, EVs=8
# Number of EVs currently served is 23.0
#
# --- Time Step 84 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=187 KWh, EVs=6
# Station 9: Load=236 KWh, EVs=7
# Station 10: Load=321 KWh, EVs=8
# Number of EVs currently served is 23.0
#
# --- Time Step 85 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=187 KWh, EVs=6
# Station 9: Load=236 KWh, EVs=7
# Station 10: Load=321 KWh, EVs=8
# Number of EVs currently served is 23.0
#
# --- Time Step 86 ---
# EV 49 has arrived with 15 KWh and needs 2 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=15 KWh, EVs=1
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=187 KWh, EVs=6
# Station 9: Load=236 KWh, EVs=7
# Station 10: Load=321 KWh, EVs=8
# Number of EVs currently served is 24.0
#
# --- Time Step 87 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=15 KWh, EVs=1
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=187 KWh, EVs=6
# Station 9: Load=236 KWh, EVs=7
# Station 10: Load=321 KWh, EVs=8
# Number of EVs currently served is 24.0
#
# --- Time Step 88 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=15 KWh, EVs=1
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=187 KWh, EVs=6
# Station 9: Load=236 KWh, EVs=7
# Station 10: Load=321 KWh, EVs=8
# Number of EVs currently served is 24.0
#
# --- Time Step 89 ---
# EV 49 has departed from Station 5.
# EV 27 has departed from Station 8.
# EV 32 has departed from Station 10.
# EV 50 has arrived with 14 KWh and needs 9 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=176 KWh, EVs=5
# Station 9: Load=236 KWh, EVs=7
# Station 10: Load=288 KWh, EVs=8
# Number of EVs currently served is 22.0
#
# --- Time Step 90 ---
# EV 29 has departed from Station 8.
# EV 33 has departed from Station 10.
# EV 51 has arrived with 44 KWh and needs 1 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=137 KWh, EVs=4
# Station 9: Load=280 KWh, EVs=8
# Station 10: Load=244 KWh, EVs=7
# Number of EVs currently served is 21.0
#
# --- Time Step 91 ---
# EV 35 has departed from Station 10.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=137 KWh, EVs=4
# Station 9: Load=280 KWh, EVs=8
# Station 10: Load=199 KWh, EVs=6
# Number of EVs currently served is 20.0
#
# --- Time Step 92 ---
# EV 36 has departed from Station 10.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=137 KWh, EVs=4
# Station 9: Load=280 KWh, EVs=8
# Station 10: Load=157 KWh, EVs=5
# Number of EVs currently served is 19.0
#
# --- Time Step 93 ---
# EV 52 has arrived with 27 KWh and needs 52 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=60 KWh, EVs=2
# Station 8: Load=137 KWh, EVs=4
# Station 9: Load=280 KWh, EVs=8
# Station 10: Load=184 KWh, EVs=6
# Number of EVs currently served is 20.0
#
# --- Time Step 94 ---
# EV 37 has departed from Station 7.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=12 KWh, EVs=1
# Station 8: Load=137 KWh, EVs=4
# Station 9: Load=280 KWh, EVs=8
# Station 10: Load=184 KWh, EVs=6
# Number of EVs currently served is 19.0
#
# --- Time Step 95 ---
# EV 39 has departed from Station 7.
# EV 53 has arrived with 18 KWh and needs 2 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=137 KWh, EVs=4
# Station 9: Load=298 KWh, EVs=9
# Station 10: Load=184 KWh, EVs=6
# Number of EVs currently served is 19.0
#
# --- Time Step 96 ---
# EV 54 has arrived with 13 KWh and needs 35 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=137 KWh, EVs=4
# Station 9: Load=311 KWh, EVs=10
# Station 10: Load=184 KWh, EVs=6
# Number of EVs currently served is 20.0
#
# --- Time Step 97 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=137 KWh, EVs=4
# Station 9: Load=311 KWh, EVs=10
# Station 10: Load=184 KWh, EVs=6
# Number of EVs currently served is 20.0
#
# --- Time Step 98 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=137 KWh, EVs=4
# Station 9: Load=311 KWh, EVs=10
# Station 10: Load=184 KWh, EVs=6
# Number of EVs currently served is 20.0
#
# --- Time Step 99 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=137 KWh, EVs=4
# Station 9: Load=311 KWh, EVs=10
# Station 10: Load=184 KWh, EVs=6
# Number of EVs currently served is 20.0
#
# --- Time Step 100 ---
# EV 55 has arrived with 44 KWh and needs 8 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=181 KWh, EVs=5
# Station 9: Load=311 KWh, EVs=10
# Station 10: Load=184 KWh, EVs=6
# Number of EVs currently served is 21.0
#
# --- Time Step 101 ---
# EV 56 has arrived with 44 KWh and needs 16 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=181 KWh, EVs=5
# Station 9: Load=311 KWh, EVs=10
# Station 10: Load=228 KWh, EVs=7
# Number of EVs currently served is 22.0
#
# --- Time Step 102 ---
# EV 57 has arrived with 17 KWh and needs 8 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=181 KWh, EVs=5
# Station 9: Load=328 KWh, EVs=11
# Station 10: Load=228 KWh, EVs=7
# Number of EVs currently served is 23.0
#
# --- Time Step 103 ---
# EV 58 has arrived with 17 KWh and needs 4 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=181 KWh, EVs=5
# Station 9: Load=345 KWh, EVs=12
# Station 10: Load=228 KWh, EVs=7
# Number of EVs currently served is 24.0
#
# --- Time Step 104 ---
# EV 59 has arrived with 45 KWh and needs 29 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=181 KWh, EVs=5
# Station 9: Load=390 KWh, EVs=13
# Station 10: Load=228 KWh, EVs=7
# Number of EVs currently served is 25.0
#
# --- Time Step 105 ---
# EV 41 has departed from Station 10.
# EV 60 has arrived with 45 KWh and needs 12 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=181 KWh, EVs=5
# Station 9: Load=390 KWh, EVs=13
# Station 10: Load=252 KWh, EVs=7
# Number of EVs currently served is 25.0
#
# --- Time Step 106 ---
# EV 44 has departed from Station 10.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=181 KWh, EVs=5
# Station 9: Load=390 KWh, EVs=13
# Station 10: Load=213 KWh, EVs=6
# Number of EVs currently served is 24.0
#
# --- Time Step 107 ---
# EV 47 has departed from Station 10.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=181 KWh, EVs=5
# Station 9: Load=390 KWh, EVs=13
# Station 10: Load=167 KWh, EVs=5
# Number of EVs currently served is 23.0
#
# --- Time Step 108 ---
# EV 61 has arrived with 43 KWh and needs 4 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=181 KWh, EVs=5
# Station 9: Load=390 KWh, EVs=13
# Station 10: Load=210 KWh, EVs=6
# Number of EVs currently served is 24.0
#
# --- Time Step 109 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=181 KWh, EVs=5
# Station 9: Load=390 KWh, EVs=13
# Station 10: Load=210 KWh, EVs=6
# Number of EVs currently served is 24.0
#
# --- Time Step 110 ---
# EV 62 has arrived with 37 KWh and needs 84 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=218 KWh, EVs=6
# Station 9: Load=390 KWh, EVs=13
# Station 10: Load=210 KWh, EVs=6
# Number of EVs currently served is 25.0
#
# --- Time Step 111 ---
# EV 63 has arrived with 11 KWh and needs 4 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=218 KWh, EVs=6
# Station 9: Load=401 KWh, EVs=14
# Station 10: Load=210 KWh, EVs=6
# Number of EVs currently served is 26.0
#
# --- Time Step 112 ---
# EV 64 has arrived with 35 KWh and needs 44 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=218 KWh, EVs=6
# Station 9: Load=401 KWh, EVs=14
# Station 10: Load=245 KWh, EVs=7
# Number of EVs currently served is 27.0
#
# --- Time Step 113 ---
# EV 65 has arrived with 20 KWh and needs 43 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=218 KWh, EVs=6
# Station 9: Load=421 KWh, EVs=15
# Station 10: Load=245 KWh, EVs=7
# Number of EVs currently served is 28.0
#
# --- Time Step 114 ---
# EV 66 has arrived with 11 KWh and needs 12 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=0 KWh, EVs=0
# Station 8: Load=218 KWh, EVs=6
# Station 9: Load=421 KWh, EVs=15
# Station 10: Load=256 KWh, EVs=8
# Number of EVs currently served is 29.0
#
# --- Time Step 115 ---
# EV 67 has arrived with 48 KWh and needs 15 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=48 KWh, EVs=1
# Station 8: Load=218 KWh, EVs=6
# Station 9: Load=421 KWh, EVs=15
# Station 10: Load=256 KWh, EVs=8
# Number of EVs currently served is 30.0
#
# --- Time Step 116 ---
# EV 48 has departed from Station 10.
# EV 68 has arrived with 28 KWh and needs 5 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=48 KWh, EVs=1
# Station 8: Load=218 KWh, EVs=6
# Station 9: Load=449 KWh, EVs=16
# Station 10: Load=219 KWh, EVs=7
# Number of EVs currently served is 30.0
#
# --- Time Step 117 ---
# EV 50 has departed from Station 10.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=48 KWh, EVs=1
# Station 8: Load=218 KWh, EVs=6
# Station 9: Load=449 KWh, EVs=16
# Station 10: Load=205 KWh, EVs=6
# Number of EVs currently served is 29.0
#
# --- Time Step 118 ---
# EV 69 has arrived with 16 KWh and needs 15 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=48 KWh, EVs=1
# Station 8: Load=218 KWh, EVs=6
# Station 9: Load=465 KWh, EVs=17
# Station 10: Load=205 KWh, EVs=6
# Number of EVs currently served is 30.0
#
# --- Time Step 119 ---
# EV 70 has arrived with 34 KWh and needs 12 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# ...
# Number of EVs currently served is 36.0
#
# --- Time Step 1404 ---
# EV 940 has arrived with 16 KWh and needs 11 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=32 KWh, EVs=1
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=39 KWh, EVs=1
# Station 8: Load=223 KWh, EVs=7
# Station 9: Load=150 KWh, EVs=5
# Station 10: Load=673 KWh, EVs=22
# Number of EVs currently served is 37.0
#
# --- Time Step 1405 ---
# EV 941 has arrived with 47 KWh and needs 52 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=32 KWh, EVs=1
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=39 KWh, EVs=1
# Station 8: Load=223 KWh, EVs=7
# Station 9: Load=150 KWh, EVs=5
# Station 10: Load=720 KWh, EVs=23
# Number of EVs currently served is 38.0
#
# --- Time Step 1406 ---
# EV 915 has departed from Station 5.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=39 KWh, EVs=1
# Station 8: Load=223 KWh, EVs=7
# Station 9: Load=150 KWh, EVs=5
# Station 10: Load=720 KWh, EVs=23
# Number of EVs currently served is 37.0
#
# --- Time Step 1407 ---
# EV 942 has arrived with 22 KWh and needs 4 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=39 KWh, EVs=1
# Station 8: Load=223 KWh, EVs=7
# Station 9: Load=172 KWh, EVs=6
# Station 10: Load=720 KWh, EVs=23
# Number of EVs currently served is 38.0
#
# --- Time Step 1408 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=39 KWh, EVs=1
# Station 8: Load=223 KWh, EVs=7
# Station 9: Load=172 KWh, EVs=6
# Station 10: Load=720 KWh, EVs=23
# Number of EVs currently served is 38.0
#
# --- Time Step 1409 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=39 KWh, EVs=1
# Station 8: Load=223 KWh, EVs=7
# Station 9: Load=172 KWh, EVs=6
# Station 10: Load=720 KWh, EVs=23
# Number of EVs currently served is 38.0
#
# --- Time Step 1410 ---
# EV 884 has departed from Station 10.
# EV 943 has arrived with 33 KWh and needs 65 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=72 KWh, EVs=2
# Station 8: Load=223 KWh, EVs=7
# Station 9: Load=172 KWh, EVs=6
# Station 10: Load=700 KWh, EVs=22
# Number of EVs currently served is 38.0
#
# --- Time Step 1411 ---
# EV 886 has departed from Station 10.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=72 KWh, EVs=2
# Station 8: Load=223 KWh, EVs=7
# Station 9: Load=172 KWh, EVs=6
# Station 10: Load=659 KWh, EVs=21
# Number of EVs currently served is 37.0
#
# --- Time Step 1412 ---
# EV 888 has departed from Station 10.
# EV 944 has arrived with 33 KWh and needs 3 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=72 KWh, EVs=2
# Station 8: Load=223 KWh, EVs=7
# Station 9: Load=172 KWh, EVs=6
# Station 10: Load=651 KWh, EVs=21
# Number of EVs currently served is 37.0
#
# --- Time Step 1413 ---
# EV 890 has departed from Station 10.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=72 KWh, EVs=2
# Station 8: Load=223 KWh, EVs=7
# Station 9: Load=172 KWh, EVs=6
# Station 10: Load=631 KWh, EVs=20
# Number of EVs currently served is 36.0
#
# --- Time Step 1414 ---
# EV 896 has departed from Station 10.
# EV 945 has arrived with 27 KWh and needs 22 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=72 KWh, EVs=2
# Station 8: Load=250 KWh, EVs=8
# Station 9: Load=172 KWh, EVs=6
# Station 10: Load=607 KWh, EVs=19
# Number of EVs currently served is 36.0
#
# --- Time Step 1415 ---
# EV 897 has departed from Station 10.
# EV 946 has arrived with 23 KWh and needs 16 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=72 KWh, EVs=2
# Station 8: Load=250 KWh, EVs=8
# Station 9: Load=172 KWh, EVs=6
# Station 10: Load=590 KWh, EVs=19
# Number of EVs currently served is 36.0
#
# --- Time Step 1416 ---
# EV 901 has departed from Station 10.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=72 KWh, EVs=2
# Station 8: Load=250 KWh, EVs=8
# Station 9: Load=172 KWh, EVs=6
# Station 10: Load=567 KWh, EVs=18
# Number of EVs currently served is 35.0
#
# --- Time Step 1417 ---
# EV 902 has departed from Station 10.
# EV 947 has arrived with 19 KWh and needs 25 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=72 KWh, EVs=2
# Station 8: Load=250 KWh, EVs=8
# Station 9: Load=191 KWh, EVs=7
# Station 10: Load=528 KWh, EVs=17
# Number of EVs currently served is 35.0
#
# --- Time Step 1418 ---
# EV 904 has departed from Station 10.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=72 KWh, EVs=2
# Station 8: Load=250 KWh, EVs=8
# Station 9: Load=191 KWh, EVs=7
# Station 10: Load=481 KWh, EVs=16
# Number of EVs currently served is 34.0
#
# --- Time Step 1419 ---
# EV 905 has departed from Station 10.
# EV 948 has arrived with 11 KWh and needs 6 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=72 KWh, EVs=2
# Station 8: Load=250 KWh, EVs=8
# Station 9: Load=191 KWh, EVs=7
# Station 10: Load=443 KWh, EVs=16
# Number of EVs currently served is 34.0
#
# --- Time Step 1420 ---
# EV 906 has departed from Station 10.
# EV 949 has arrived with 46 KWh and needs 125 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=72 KWh, EVs=2
# Station 8: Load=250 KWh, EVs=8
# Station 9: Load=237 KWh, EVs=8
# Station 10: Load=430 KWh, EVs=15
# Number of EVs currently served is 34.0
#
# --- Time Step 1421 ---
# EV 907 has departed from Station 10.
# EV 950 has arrived with 31 KWh and needs 1 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=72 KWh, EVs=2
# Station 8: Load=250 KWh, EVs=8
# Station 9: Load=237 KWh, EVs=8
# Station 10: Load=430 KWh, EVs=15
# Number of EVs currently served is 34.0
#
# --- Time Step 1422 ---
# EV 913 has departed from Station 10.
# EV 951 has arrived with 31 KWh and needs 9 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=72 KWh, EVs=2
# Station 8: Load=250 KWh, EVs=8
# Station 9: Load=237 KWh, EVs=8
# Station 10: Load=442 KWh, EVs=15
# Number of EVs currently served is 34.0
#
# --- Time Step 1423 ---
# EV 914 has departed from Station 10.
# EV 952 has arrived with 11 KWh and needs 25 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=72 KWh, EVs=2
# Station 8: Load=250 KWh, EVs=8
# Station 9: Load=237 KWh, EVs=8
# Station 10: Load=438 KWh, EVs=15
# Number of EVs currently served is 34.0
#
# --- Time Step 1424 ---
# EV 916 has departed from Station 10.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=72 KWh, EVs=2
# Station 8: Load=250 KWh, EVs=8
# Station 9: Load=237 KWh, EVs=8
# Station 10: Load=396 KWh, EVs=14
# Number of EVs currently served is 33.0
#
# --- Time Step 1425 ---
# EV 917 has departed from Station 10.
# EV 953 has arrived with 18 KWh and needs 32 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=90 KWh, EVs=3
# Station 8: Load=250 KWh, EVs=8
# Station 9: Load=237 KWh, EVs=8
# Station 10: Load=357 KWh, EVs=13
# Number of EVs currently served is 33.0
#
# --- Time Step 1426 ---
# EV 923 has departed from Station 10.
# EV 954 has arrived with 31 KWh and needs 65 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=90 KWh, EVs=3
# Station 8: Load=281 KWh, EVs=9
# Station 9: Load=237 KWh, EVs=8
# Station 10: Load=321 KWh, EVs=12
# Number of EVs currently served is 33.0
#
# --- Time Step 1427 ---
# EV 955 has arrived with 14 KWh and needs 3 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=90 KWh, EVs=3
# Station 8: Load=281 KWh, EVs=9
# Station 9: Load=237 KWh, EVs=8
# Station 10: Load=335 KWh, EVs=13
# Number of EVs currently served is 34.0
#
# --- Time Step 1428 ---
# EV 956 has arrived with 34 KWh and needs 6 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=90 KWh, EVs=3
# Station 8: Load=281 KWh, EVs=9
# Station 9: Load=237 KWh, EVs=8
# Station 10: Load=369 KWh, EVs=14
# Number of EVs currently served is 35.0
#
# --- Time Step 1429 ---
# EV 957 has arrived with 27 KWh and needs 11 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=90 KWh, EVs=3
# Station 8: Load=281 KWh, EVs=9
# Station 9: Load=264 KWh, EVs=9
# Station 10: Load=369 KWh, EVs=14
# Number of EVs currently served is 36.0
#
# --- Time Step 1430 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=90 KWh, EVs=3
# Station 8: Load=281 KWh, EVs=9
# Station 9: Load=264 KWh, EVs=9
# Station 10: Load=369 KWh, EVs=14
# Number of EVs currently served is 36.0
#
# --- Time Step 1431 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=90 KWh, EVs=3
# Station 8: Load=281 KWh, EVs=9
# Station 9: Load=264 KWh, EVs=9
# Station 10: Load=369 KWh, EVs=14
# Number of EVs currently served is 36.0
#
# --- Time Step 1432 ---
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=90 KWh, EVs=3
# Station 8: Load=281 KWh, EVs=9
# Station 9: Load=264 KWh, EVs=9
# Station 10: Load=369 KWh, EVs=14
# Number of EVs currently served is 36.0
#
# --- Time Step 1433 ---
# EV 958 has arrived with 22 KWh and needs 1 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=90 KWh, EVs=3
# Station 8: Load=281 KWh, EVs=9
# Station 9: Load=286 KWh, EVs=10
# Station 10: Load=369 KWh, EVs=14
# Number of EVs currently served is 37.0
#
# --- Time Step 1434 ---
# EV 959 has arrived with 15 KWh and needs 7 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=90 KWh, EVs=3
# Station 8: Load=281 KWh, EVs=9
# Station 9: Load=286 KWh, EVs=10
# Station 10: Load=384 KWh, EVs=15
# Number of EVs currently served is 38.0
#
# --- Time Step 1435 ---
# EV 960 has arrived with 27 KWh and needs 60 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=90 KWh, EVs=3
# Station 8: Load=281 KWh, EVs=9
# Station 9: Load=286 KWh, EVs=10
# Station 10: Load=411 KWh, EVs=16
# Number of EVs currently served is 39.0
#
# --- Time Step 1436 ---
# EV 961 has arrived with 10 KWh and needs 1 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=90 KWh, EVs=3
# Station 8: Load=281 KWh, EVs=9
# Station 9: Load=286 KWh, EVs=10
# Station 10: Load=421 KWh, EVs=17
# Number of EVs currently served is 40.0
#
# --- Time Step 1437 ---
# EV 962 has arrived with 44 KWh and needs 37 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=16 KWh, EVs=1
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=90 KWh, EVs=3
# Station 8: Load=281 KWh, EVs=9
# Station 9: Load=330 KWh, EVs=11
# Station 10: Load=421 KWh, EVs=17
# Number of EVs currently served is 41.0
#
# --- Time Step 1438 ---
# EV 937 has departed from Station 3.
# EV 963 has arrived with 46 KWh and needs 66 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=90 KWh, EVs=3
# Station 8: Load=281 KWh, EVs=9
# Station 9: Load=376 KWh, EVs=12
# Station 10: Load=421 KWh, EVs=17
# Number of EVs currently served is 41.0
#
# --- Time Step 1439 ---
# EV 964 has arrived with 21 KWh and needs 28 time steps.
# Station 1: Load=0 KWh, EVs=0
# Station 2: Load=0 KWh, EVs=0
# Station 3: Load=0 KWh, EVs=0
# Station 4: Load=0 KWh, EVs=0
# Station 5: Load=0 KWh, EVs=0
# Station 6: Load=0 KWh, EVs=0
# Station 7: Load=90 KWh, EVs=3
# Station 8: Load=281 KWh, EVs=9
# Station 9: Load=376 KWh, EVs=12
# Station 10: Load=442 KWh, EVs=18
# Number of EVs currently served is 42.0
#
# --- Simulation Completed ---
#
# Station 1 final load: 0 KWh, serving 0 EVs.
# Station 2 final load: 0 KWh, serving 0 EVs.
# Station 3 final load: 0 KWh, serving 0 EVs.
# Station 4 final load: 0 KWh, serving 0 EVs.
# Station 5 final load: 0 KWh, serving 0 EVs.
# Station 6 final load: 0 KWh, serving 0 EVs.
# Station 7 final load: 90 KWh, serving 3 EVs.
# Station 8 final load: 281 KWh, serving 9 EVs.
# Station 9 final load: 376 KWh, serving 12 EVs.
# Station 10 final load: 442 KWh, serving 18 EVs.
# Total EVs Departed: 923
# Total EVs Active: 42
# Execution time: 0.21443510055541992 seconds
# Average PAR for Station Energy across 1440 steps is 5.958831898327991.
# Average PAR Waiting Time across 1440 steps is 3.760637044550428.
# Average Waiting Time across 1440 steps is 11.236206249730417.

# %%
df = pd.DataFrame({'Time': timelist, 'Station': stlist, 'Load': loadlist, 'EV_count':evlist})

# %%
df.to_csv("RandomAssignment_results_stepwise.csv", index=False)

# %%
import plotly.graph_objects as go
import pandas as pd # Assuming your data is in a pandas DataFrame

# Sample Data Structure (replace with your actual data parsing)
# df should have columns like 'time', 'station', 'ev_count'
# For example:
# time | station | ev_count
# -----|---------|----------
# 1    | A       | 5
# 1    | B       | 3
# 2    | A       | 4
# 2    | B       | 6

# Assume 'df' is your DataFrame
times = sorted(df['Time'].unique())
stations = sorted(df['Station'].unique())

fig = go.Figure(
     data=[
         go.Bar(
             x=stations,
             y=df[df['Time'] == times[0]]['EV_count'], # Initial frame
             name='EVs Served'
         )
     ],
     layout=go.Layout(
         xaxis=dict(title='Stations'),
         yaxis=dict(title='Number of EVs in Queue'),
         title='EV Queue Status Over Time - Random Selection',
         updatemenus=[dict(
             type='buttons',
             showactive=False,
             buttons=[dict(label='Play',
                             method='animate',
                             args=[None, dict(frame=dict(duration=500, redraw=True), fromcurrent=True)])]
         )]
     ),
     frames=[
         go.Frame(
             data=[go.Bar(x=stations, y=df[df['Time'] == t]['EV_count'])],
             name=str(t) # Frame name
         ) for t in times
     ]
 )

fig.update_layout(
     sliders=[dict(
         steps = [dict(method='animate', args=[[str(t)], dict(mode='immediate', frame=dict(duration=500, redraw=True), transition=dict(duration=0))], label=str(t)) for t in times],
         active = 0,
         currentvalue = {"prefix": "Time: "},
         pad = {"t": 50}
     )]
 )

fig.show()

# %%
import plotly.io as pio
pio.write_html(fig, file='interactive_Random.html', auto_open=True)
